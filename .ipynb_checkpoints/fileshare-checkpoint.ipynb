# %%
import http.server
import socketserver

PORT = 8000
handler = http.server.SimpleHTTPRequestHandler

with socketserver.TCPServer(("", PORT), handler) as http:
    print("File Transfer Server Running on Port", PORT)
    print("Open this in your browser:  http://localhost:8000")
    http.serve_forever()

# %%
import http.server
import socketserver
import os
PORT = 8000
DIRECTORY = r"C:\Users\hriti\trial"
os.makedirs(DIRECTORY, exist_ok=True)
class Handler(http.server.SimpleHTTPRequestHandler):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, directory=DIRECTORY, **kwargs)
with socketserver.TCPServer(("", PORT), Handler) as http:
    print("Serving files from:", DIRECTORY)
    print("Open in browser: http://localhost:8000")
    http.serve_forever()
# Out:
# Serving files from: C:\Users\hriti\trial
# Open in browser: http://localhost:8000
# 127.0.0.1 - - [28/Nov/2025 18:53:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Nov/2025 18:53:14] code 404, message File not found
# 127.0.0.1 - - [28/Nov/2025 18:53:14] "GET /favicon.ico HTTP/1.1" 404 -
