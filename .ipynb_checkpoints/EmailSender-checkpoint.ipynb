# %%
import email.message

# %%
import smtplib 
import ssl
from email.message import EmailMessage
EMAIL = "hritikshk01@gmail.com"
APP_PASSWORD = ""
RECEIVER = "deepakdiya18@gmail.com"
msg = EmailMessage()
msg ["From"] = EMAIL
msg["To"] = RECEIVER
msg["Subject"] = "Hello From Python........"
msg.set_content("This is send by the Python code.....")
context = ssl.create_default_context()
with smtplib.SMTP_SSL("smtp.gmail.com",465 , context=context) as server: 
    server.set_debuglevel(1)
    server.login(EMAIL, APP_PASSWORD)
    server.send_message(msg)
print("Email Sent Successfully___")
# Out:
# send: 'ehlo [10.106.79.226]\r\n'
# reply: b'250-smtp.gmail.com at your service, [2409:40d4:310f:cdfb:80b9:e3b1:cec4:8552]\r\n'
# reply: b'250-SIZE 35882577\r\n'
# reply: b'250-8BITMIME\r\n'
# reply: b'250-AUTH LOGIN PLAIN XOAUTH2 PLAIN-CLIENTTOKEN OAUTHBEARER XOAUTH\r\n'
# reply: b'250-ENHANCEDSTATUSCODES\r\n'
# reply: b'250-PIPELINING\r\n'
# reply: b'250-CHUNKING\r\n'
# reply: b'250 SMTPUTF8\r\n'
# reply: retcode (250); Msg: b'smtp.gmail.com at your service, [2409:40d4:310f:cdfb:80b9:e3b1:cec4:8552]\nSIZE 35882577\n8BITMIME\nAUTH LOGIN PLAIN XOAUTH2 PLAIN-CLIENTTOKEN OAUTHBEARER XOAUTH\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8'
# send: 'AUTH PLAIN AGhyaXRpa3NoazAxQGdtYWlsLmNvbQA=\r\n'
# reply: b'535-5.7.8 Username and Password not accepted. For more information, go to\r\n'
# reply: b'535 5.7.8  https://support.google.com/mail/?p=BadCredentials d9443c01a7336-29bceb5c6c9sm60308785ad.97 - gsmtp\r\n'
# reply: retcode (535); Msg: b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d9443c01a7336-29bceb5c6c9sm60308785ad.97 - gsmtp'
# send: 'AUTH LOGIN aHJpdGlrc2hrMDFAZ21haWwuY29t\r\n'
# reply: b'334 UGFzc3dvcmQ6\r\n'
# reply: retcode (334); Msg: b'UGFzc3dvcmQ6'
# send: '\r\n'
# reply: b'535-5.7.8 Username and Password not accepted. For more information, go to\r\n'
# reply: b'535 5.7.8  https://support.google.com/mail/?p=BadCredentials d9443c01a7336-29bceb5c6c9sm60308785ad.97 - gsmtp\r\n'
# reply: retcode (535); Msg: b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d9443c01a7336-29bceb5c6c9sm60308785ad.97 - gsmtp'
# send: 'QUIT\r\n'
# reply: b'221 2.0.0 closing connection d9443c01a7336-29bceb5c6c9sm60308785ad.97 - gsmtp\r\n'
# reply: retcode (221); Msg: b'2.0.0 closing connection d9443c01a7336-29bceb5c6c9sm60308785ad.97 - gsmtp'
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[1], line 15
#      13 with smtplib.SMTP_SSL("smtp.gmail.com",465 , context=context) as server:
#      14     server.set_debuglevel(1)
# ---> 15     server.login(EMAIL, APP_PASSWORD)
#      16     server.send_message(msg)
#      17 print("Email Sent Successfully___")
#
# File ~\anaconda3\Lib\smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File ~\anaconda3\Lib\smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
#     741         initial_response_ok=initial_response_ok)
#     742     # 235 == 'Authentication successful'
#     743     # 503 == 'Error: already authenticated'
#     744     if code in (235, 503):
#
# File ~\anaconda3\Lib\smtplib.py:662, in SMTP.auth(self, mechanism, authobject, initial_response_ok)
#     660 if code in (235, 503):
#     661     return (code, resp)
# --> 662 raise SMTPAuthenticationError(code, resp)
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d9443c01a7336-29bceb5c6c9sm60308785ad.97 - gsmtp')

# %%
filetransferapp chatbot game

# %%
onodaytiwckmmdtx
