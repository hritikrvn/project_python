# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def resume():
    return """
    <h1>My Resume</h1>
    <h2>Contact</h2>
    <p>Email: hritikshk01@email.com</p>
    <p>Phone: +916206946290</p>
    <h2>Skills</h2>
    <p>HTML, Python, Flask</p>
    <h2>Education</h2>
    <p>B.Tech in Computer Science (2018–2022)</p>
    <h2>Projects</h2>
    <p>Flask API, Text-To-Speach, ATM with sms alert</p>
    """

if __name__ == "__main__":
    app.run(debug=True)

# %%
app = Flask(__name__)

@app.route("/")
def home():
    return """
    <h1> I am Misti </h1>
    <h2> I am his girlfriend </h2>
    """
@app.route("/about")
def abouta():
    return"""
    <h1>I read books</h1>
    <h2>I like cultural books</h2>
    """
if __name__ =='__main__':
    app.run(debug=True)
