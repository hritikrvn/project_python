# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as mpl
import numpy as np

st.title("Sonali _🪷_ Ayurvedas")
st.text("Welcome To Sonali Ayurvedas")
st.write("Tradition That heals", 13+9)

herbs = pd.DataFrame([
    {"Herb": "Ashwagandha", "Catagory": "Energy", "InStock": 174},
    {"Herb": "Tulsi", "Category": "Immunity", "InStock": 300},
    {"Herb": "Triphala", "Category": "Digestive", "InStock": 108},
    {"Herb": "Brahmi", "Category": "Memory", "InStock": 75},
    {"Herb": "Turmeric", "Category": "Anti-inflammatory", "InStock": 500},
    {"Herb": "Shilajeet", "Category": "Vitality", "InStock": 59},])

st.subheader("Herb Details")
st.dataframe(herbs)

name = st.text_input("Enter Your Name")
age = st.number_input("Enter Your Age:", 1,120)
problems = st.text_input("Enter Your Problems:")
herb = st.selectbox("Select prescribed herb:", ["Ashwagandha", "Tulsi", "Triphala", "Brahmi", "Turmeric", "Shilajeet"])

if st.button("Save Info"):
    st.success("Info Saved")
file = st.file_uploader("Upload Your Report")
if file:
    content = st.read()
    st.write("file uploaded successfulle!!!")

if "data" not in st.session_state:
    st.session_state.data = []

if st.button("Save Entry"):
    st.session_state.data.append({
        "Name": name,
        "Age": age,
        "Problem": problem,
        "Herb": herb
    })
    st.success("Customer Saved Successfully!")

if st.session_state.data:
    df = pd.DataFrame(st.session_state.data)
    st.subheader("📋 Customer Records")
    st.dataframe(df)
    st.subheader("📊 Herb Usage (Line Chart)")
    st.line_chart(df["Herb"].value_counts())
    st.subheader("📊 Herb Usage (Bar Chart)")
    st.bar_chart(df["Herb"].value_counts())
    plt.bar(herbs,InStocks)

st.subheader("🧪 Herb Stock Pie Chart")

InStocks = herbs["InStock"]
Labels = herbs["Herb"]

fig , ax = mpl.subplots()
ax.pie(InStocks, labels=Labels, autopct="%1.1f%%")
st.pyplot(fig)
# Out:
# 2025-11-27 01:22:30.561 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 01:22:30.898
# ...
#   command:
#
#     streamlit run C:\Users\hriti\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-27 01:22:30.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 01:22:30.900 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 01:22:30.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 01:22:30.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 01:22:30.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
